# %%
import pandas as pd
import numpy as np
import os
import re

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pcrrt\\Applied NLP Final Project\\Code\\Data Build'

# %%
inpath="C:/Users/pcrrt/Applied NLP Final Project/Data/Source Data/Rev.com/"
inpath2="C:/Users/pcrrt/Applied NLP Final Project/Data/Intermediate Data/"

# %%
files_dict={}
for f in os.listdir(inpath):
    with open(inpath+f, encoding='utf-8') as file:
        files_dict[f] = "".join([i for i in file.readlines() if i not in ('(APPLAUSE)\n', '\n', '(APPLAUSE)', '(BOOING)\n)', '(LAUGHTER)\n', '(CROWD CHANTING)\n')]) 
#files_df=pd.DataFrame.from_dict(kaggle_files_dict, orient='index').reset_index()

# %%
search_for_notdonald=re.compile(r'\n(?!Donald Trump).*\:\s\(\d{2}\:\d{2}.*\)')
search_for_donald=re.compile(r'(Donald Trump\:\s{1,3}\(\d{2}\:\d{2}.*\))')
search_for_speaker=re.compile(r'(Donald Trump\:\s{1,3}\(\d{2}\:\d{2}.*\)|\n(?!Donald Trump).*\:\s\(\d{2}\:\d{2}.*\))')
#search_for_donald=re.compile(r'\nDonald Trump: \(26\:26\)\n\(singing\)')
final_list=[]
x=[]
for n in files_dict.values():
    if re.search(search_for_speaker, n):
        x=re.findall(search_for_speaker, n)
    #x=list(set([re.search(search_for, i).group(0) for i in n if re.search(search_for, i)]))
    final_list=final_list+x
final_list=list(set(final_list))
final_list
# Out:
# ['\nMike Pence: (02:01:16)',
#  'Donald Trump: (01:23:50)',
#  '\nMike Pence: (30:44)',
#  'Donald Trump: (01:03:19)',
#  '\nPresident Trump: (23:04)',
#  '\nPeter Navarro: (01:08:27)',
#  'Donald Trump: (05:42)',
#  'Donald Trump: (40:04)',
#  'Donald Trump: (17:03)',
#  '\nBill Hemmer: (31:35)',
#  '\nSpeaker 11: (01:02:19)',
#  'Donald Trump: (01:00:12)',
#  'Donald Trump: (01:23:36)',
#  'Donald Trump: (53:37)',
#  '\nSpeaker 5: (44:28)',
#  'Donald Trump: (43:37)',
#  '\nRebecca Long: (29:14)',
#  'Donald Trump: (01:00:26)',
#  'Donald Trump: (17:30)',
#  'Donald Trump: (23:11)',
#  '\nMike Pence: (01:07:10)',
#  '\nMale Reporter: (01:41:37)',
#  '\nBret Baier: (15:47)',
#  'Donald Trump: (01:07:13)',
#  'Donald Trump: (26:40)',
#  '\nPresident Trump: (33:26)',
#  'Donald Trump: (02:39)',
#  '\nSpeaker 5: (01:35:33)',
#  '\nDan: (54:03)',
#  '\nAnthony Fauci: (01:36:00)',
#  '\nOscar: (12:25)',
#  'Donald Trump: (45:20)',
#  'Donald Trump: (51:10)',
#  '\nSecretary Mnuchin: (36:47)',
#  '\nPresident Donald Trump: (05:20)',
#  '\nMike Pence: (18:03)',
#  '\nJohn: (04:08)',
#  '\nMark H.: (13:18)',
#  '\nKelly: (01:17:13)',
#  'Donald Trump: (29:39)',
#  'Donald Trump: (14:31)',
#  '\nJournalist 10: (01:35:45)',
#  'Donald Trump: (56:31)',
#  'Donald Trump: (47:51)',
#  '\nSpeaker 73: (01:21:25)',
#  'Donald Trump: (10:45)',
#  '\nSpeaker 21: (01:40:01)',
#  '\nSpeaker 7: (25:38)',
#  'Donald Trump: (49:05)',
#  '\nDr. Birx: (25:13)',
#  'Donald Trump: (15:15)',
#  '\nDr. Deborah Birx: (31:50)',
#  'Donald Trump: (03:47)',
#  'Donald Trump: (38:22)',
#  '\nPresident Trump: (38:55)',
#  '\nJournalist 5: (01:44:01)',
#  '\nSpeaker 13: (06:01)',
#  '\nMale Reporter: (01:41:22)',
#  '\nReporter: (54:55)',
#  '\nMacron: (31:15)',
#  '\nFrancis Collins: (00:50)',
#  'Donald Trump: (18:39)',
#  '\nSpeaker 2: (15:10)',
#  'Donald Trump: (32:55)',
#  '\nSecretary Chad Wolf: (39:47)',
#  '\nSpeaker 8: (58:29)',
#  '\nVice President Pence: (09:17)',
#  '\nSteve Mnuchin: (41:03)',
#  '\nSteve Mnuchin: (20:20)',
#  'Donald Trump: (52:20)',
#  '\nSpeaker 2: (27:42)',
#  '\nDonald J Trump: (01:01)',
#  '\nMike Pence: (01:15:14)',
#  'Donald Trump: (01:42:11)',
#  'Donald Trump: (40:31)',
#  'Donald Trump: (51:01)',
#  '\nReporter: (01:05:54)',
#  'Donald Trump: (23:36)',
#  'Donald Trump: (01:46:16)',
#  '\nStephane Bancel: (18:05)',
#  '\nSpeaker 15: (33:50)',
#  '\nMark Esper: (35:52)',
#  '\nSpeaker 9: (49:24)',
#  'Donald Trump: (06:33)',
#  'Donald Trump: (01:09:34)',
#  'Donald Trump: (23:02)',
#  '\nPresident Donald Trump: (05:51)',
#  '\nSpeaker 27: (50:48)',
#  '\nLois Hockersmith: (31:12)',
#  '\nJohn: (01:16:58)',
#  '\nPresident Trump: (08:21)',
#  '\nAlex Azar: (26:42)',
#  '\nMike Pence: (48:35)',
#  '\nDeborah Birx: (01:15:28)',
#  '\nBret Baier: (10:37)',
#  '\nDeborah Birx: (01:15:05)',
#  'Donald Trump: (01:08:12)',
#  '\nSpeaker 5: (43:15)',
#  '\nPresident Donald Trump: (19:16)',
#  '\nSpeaker 14: (32:07)',
#  '\nSpeaker 8: (55:59)',
#  '\nMark Esper: (37:36)',
#  '\nJohn: (55:51)',
#  'Donald Trump: (01:12:54)',
#  '\nJohn: (50:01)',
#  'Donald Trump: (28:29)',
#  '\nPresident Trump: (47:51)',
#  '\nYamiche A.: (48:29)',
#  '\nSpeaker 19: (57:11)',
#  'Donald Trump: (13:33)',
#  '\nCrowd: (35:10)',
#  'Donald Trump: (18:57)',
#  '\nAnthony Fauci: (17:56)',
#  'Donald Trump: (49:09)',
#  '\nChad Wolf: (20:37)',
#  '\nDeborah Birx: (01:06:03)',
#  '\nNetanyahu: (07:45)',
#  '\nPresident Donald Trump: (06:41)',
#  'Donald Trump: (48:06)',
#  '\nSpeaker 1: (17:54)',
#  '\nBetsy DeVos: (01:18:16)',
#  '\nSpeaker 86: (01:41:42)',
#  '\nMike Pence: (39:48)',
#  'Donald Trump: (49:58)',
#  '\nBenjamin N.: (37:39)',
#  '\nSpeaker 9: (59:56)',
#  'Donald Trump: (01:12)',
#  'Donald Trump: (49:46)',
#  '\nBill Hemmer: (08:09)',
#  'Donald Trump: (08:03)',
#  '\nSpeaker 7: (30:36)',
#  'Donald Trump: (45:58)',
#  '\nDr. Birx: (01:54:36)',
#  '\nSpeaker 5: (11:29)',
#  'Donald Trump: (29:43)',
#  'Donald Trump: (08:47)',
#  '\nAnthony Fauci: (01:11:27)',
#  '\nSpeaker 12: (01:03:03)',
#  '\nDr. Deborah Birx: (02:03:13)',
#  'Donald Trump: (22:30)',
#  'Donald Trump: (14:56)',
#  'Donald Trump: (26:11)',
#  '\nSpeaker 11: (38:13)',
#  '\nMark Esper: (33:09)',
#  '\nJournalist 8: (01:25:18)',
#  'Donald Trump: (07:51)',
#  '\nSteve Mnuchin: (32:37)',
#  '\nDeborah Birx: (01:05:32)',
#  '\nDr. Tony Fauci: (36:28)',
#  'Donald Trump: (07:34)',
#  'Donald Trump: (01:35:59)',
#  '\nSpeaker 3: (16:42)',
#  '\nReporter #9: (52:50)',
#  'Donald Trump: (18:15)',
#  'Donald Trump: (01:09:16)',
#  '\nSpeaker 13: (12:40)',
#  'Donald Trump: (15:31)',
#  'Donald Trump: (50:27)',
#  '\nSpeaker 24: (45:21)',
#  'Donald Trump: (01:42:00)',
#  'Donald Trump: (40:33)',
#  'Donald Trump: (02:48)',
#  '\nPresident Donald Trump: (14:38)',
#  '\nSpeaker 9: (01:00:55)',
#  '\nDr. Birx: (01:12:20)',
#  'Donald Trump: (44:43)',
#  '\nSpeaker 3: (38:19)',
#  'Donald Trump: (02:13)',
#  '\nAudience Member: (01:29:33)',
#  '\nJimmy Chan: (41:41)',
#  '\nDr. Fauci: (34:51)',
#  '\nAlex Azar: (25:54)',
#  '\nChad Wolf: (20:08)',
#  '\nInterpreter: (17:03)',
#  'Donald Trump: (16:43)',
#  '\nMr. Chan: (01:23:17)',
#  '\nDr. Tony Fauci: (18:53)',
#  '\nSpeaker 13: (42:29)',
#  'Donald Trump: (12:20)',
#  '\nSpeaker 19: (52:44)',
#  '\nSpeaker 24: (01:09:17)',
#  '\nPresident Trump: (24:27)',
#  'Donald Trump: (01:04:20)',
#  '\nDoctor Birx: (01:02:45)',
#  '\nDr. Fauci: (44:01)',
#  'Donald Trump: (01:44:33)',
#  '\nJohn: (56:01)',
#  '\nMike Pence: (33:15)',
#  '\nDaniel: (22:30)',
#  'Donald Trump: (01:46:42)',
#  'Donald Trump: (41:19)',
#  'Donald Trump: (01:06:19)',
#  '\nReporter: (01:21:48)',
#  'Donald Trump: (46:33)',
#  '\nBill Hemmer: (49:29)',
#  '\nSpeaker 15: (20:43)',
#  '\nSpeaker 8: (01:45:20)',
#  '\nMike Pence: (36:27)',
#  'Donald Trump: (26:17)',
#  '\nGroup: (45:20)',
#  '\nChris Nasetta: (05:35)',
#  '\nReporter 3: (01:13:50)',
#  '\nSpeaker 2: (23:44)',
#  '\nSpeaker 22: (01:10:03)',
#  'Donald Trump: (31:55)',
#  '\nVice President Mike Pence: (01:39)',
#  '\nPresident Donald Trump: (03:47)',
#  '\nMark Esper: (18:03)',
#  '\nMike Pence: (36:56)',
#  'Donald Trump: (01:14:10)',
#  'Donald Trump: (43:49)',
#  'Donald Trump: (01:00:02)',
#  '\nRuss Vought: (48:03)',
#  'Donald Trump: (03:32)',
#  '\nPrime Minister Varadkar: (22:16)',
#  '\nSpeaker 1: (21:38)',
#  '\nAudience: (59:12)',
#  'Donald Trump: (19:18)',
#  'Donald Trump: (01:06:57)',
#  '\nSpeaker 12: (01:06:53)',
#  '\nDeborah Birx: (01:27:12)',
#  '\nSpeaker 10: (37:32)',
#  '\nChris Nasetta: (06:16)',
#  '\nSpeaker 21: (01:07:19)',
#  'Donald Trump: (01:08:59)',
#  'Donald Trump: (57:12)',
#  'Donald Trump: (01:42:22)',
#  'Donald Trump: (14:27)',
#  '\nMike Pence: (40:43)',
#  'Donald Trump: (02:00:03)',
#  '\nJournalist 10: (01:42:15)',
#  '\nBret Baier: (18:55)',
#  'Donald Trump: (01:26)',
#  'Donald Trump: (16:27)',
#  'Donald Trump: (11:10)',
#  '\nPresident Trump: (07:39)',
#  '\nJohn: (27:01)',
#  'Donald Trump: (39:18)',
#  'Donald Trump: (00:29)',
#  'Donald Trump: (03:13)',
#  '\nBenjamin N.: (31:27)',
#  'Donald Trump: (46:56)',
#  'Donald Trump: (43:06)',
#  '\nPresident Trump: (38:14)',
#  '\nDr. Fauci: (01:05:58)',
#  'Donald Trump: (01:38:13)',
#  '\nRobert Redfield: (26:36)',
#  '\nCrowd: (34:05)',
#  '\nMike Pence: (01:10:24)',
#  '\nRuss Vought: (48:43)',
#  '\nSpeaker 17: (41:20)',
#  '\nReporters: (34:52)',
#  '\nAudience: (59:35)',
#  'Donald Trump: (42:48)',
#  '\nMartha MacCallum: (07:09)',
#  '\nSpeaker 31: (55:45)',
#  'Donald Trump: (10:13)',
#  '\nMike Pence: (30:55)',
#  '\nJennifer: (58:33)',
#  '\nAudience: (20:24)',
#  'Donald Trump: (16:38)',
#  'Donald Trump: (01:02:06)',
#  '\nRichard Bates: (18:17)',
#  '\nSpeaker 6: (40:29)',
#  '\nSeema Verma: (30:03)',
#  '\nSpeaker 5: (30:12)',
#  '\nAudience Member: (01:27:14)',
#  'Donald Trump: (01:15:25)',
#  'Donald Trump: (02:07:17)',
#  'Donald Trump: (50:36)',
#  '\nReporters: (08:09)',
#  '\nMike Pence: (01:22:54)',
#  '\nSpeaker 26: (01:05:34)',
#  '\nJournalist 11: (01:38:52)',
#  '\nMike Pence: (01:06:36)',
#  '\nPresident Trump: (09:11)',
#  'Donald Trump: (20:47)',
#  'Donald Trump: (47:53)',
#  'Donald Trump: (17:04)',
#  'Donald Trump: (19:58)',
#  '\nSpeaker 11 Louis?: (34:55)',
#  'Donald Trump: (27:29)',
#  'Donald Trump: (49:15)',
#  '\nJohn Polowczyk: (34:36)',
#  '\nSpeaker 3: (38:39)',
#  'Donald Trump: (01:09:57)',
#  'Donald Trump: (01:54)',
#  'Donald Trump: (18:26)',
#  'Donald Trump: (18:45)',
#  '\nMike Pence: (48:43)',
#  'Donald Trump: (14:26)',
#  'Donald Trump: (03:22)',
#  '\nPence: (01:22:03)',
#  'Donald Trump: (01:16:51)',
#  '\nDr. Deborah Birx: (01:05:05)',
#  '\nTranslator 1: (13:52)',
#  'Donald Trump: (38:21)',
#  'Donald Trump: (01:16:03)',
#  '\nSpeaker 23: (01:13:21)',
#  '\nDonald J Trump: (13:32)',
#  '\nInterpreter: (15:22)',
#  '\nSpeaker 8: (25:53)',
#  '\nDr. Deborah Birx: (01:56:26)',
#  '\nSpeaker 6: (30:08)',
#  'Donald Trump: (02:12:20)',
#  '\nSpeaker 2: (32:29)',
#  '\nOscar: (13:04)',
#  '\nMark Esper: (41:46)',
#  'Donald Trump: (01:02:34)',
#  '\nAudience Member: (01:30:41)',
#  '\nMike Lindell: (18:24)',
#  'Donald Trump: (01:44:17)',
#  '\nSpeaker 5: (34:46)',
#  'Donald Trump: (47:16)',
#  '\nSteve: (36:36)',
#  '\nDr. Berks: (33:35)',
#  '\nSpeaker 2: (12:20)',
#  '\nSpeaker 3: (30:12)',
#  'Donald Trump: (50:32)',
#  '\nSteve Mnuchin: (22:19)',
#  'Donald Trump: (54:40)',
#  '\nMike Pence: (40:15)',
#  '\nReporters: (40:28)',
#  '\nAnthony Fauci: (01:31:13)',
#  '\nDeborah Birx: (54:04)',
#  '\nBrian Kemp: (26:26)',
#  '\nSpeaker 6: (20:40)',
#  'Donald Trump: (01:06:29)',
#  '\nSpeaker 27: (02:03:02)',
#  'Donald Trump: (00:18)',
#  '\nSteve: (02:52)',
#  '\nPresident Trump: (10:35)',
#  '\nSpeaker 13: (52:08)',
#  '\nSpeaker 11: (47:45)',
#  '\nPresident Donald Trump: (01:12:14)',
#  '\nMale Reporter: (01:33:43)',
#  '\nSpeaker 14: (16:20)',
#  '\nTony Lowden: (37:45)',
#  '\nSpeaker 10: (58:56)',
#  'Donald Trump: (05:30)',
#  'Donald Trump: (25:12)',
#  '\nSpeaker 32: (01:14:10)',
#  'Donald Trump: (11:43)',
#  '\nPresident Donald Trump: (01:14:16)',
#  '\nSpeaker 14: (32:03)',
#  '\nPresident Trump: (32:44)',
#  'Donald Trump: (55:10)',
#  'Donald Trump: (01:10:01)',
#  'Donald Trump: (41:17)',
#  'Donald Trump: (11:26)',
#  'Donald Trump: (02:02:43)',
#  'Donald Trump: (01:13:36)',
#  '\nDonald J Trump: (10:16)',
#  '\nReporter 8: (01:07:35)',
#  '\nSpeaker 3: (19:33)',
#  '\nMike Pence: (01:05:18)',
#  '\nSec. Pompeo: (01:02:50)',
#  'Donald Trump: (26:34)',
#  'Donald Trump: (32:54)',
#  'Donald Trump: (05:54)',
#  '\nDr. Fauci: (56:02)',
#  'Donald Trump: (59:10)',
#  'Donald Trump: (01:07:33)',
#  'Donald Trump: (30:54)',
#  'Donald Trump: (38:32)',
#  '\nKevin McCarthy: (00:27)',
#  'Donald Trump: (01:09:18)',
#  '\nRobert Bresnahan: (08:02)',
#  'Donald Trump: (41:29)',
#  '\nSpeaker 11: (48:47)',
#  '\nDr. Fauci: (01:31:06)',
#  '\nReporter: (58:12)',
#  '\nMike Pence: (24:07)',
#  'Donald Trump: (16:55)',
#  '\nSteve Mnuchin: (35:57)',
#  'Donald Trump: (01:05:08)',
#  '\nReporter 1: (13:40)',
#  '\nAdmiral Giroir: (22:24)',
#  '\nSpeaker 3: (33:09)',
#  '\nSpeaker 16: (01:05:26)',
#  '\nSpeaker 17: (06:26)',
#  '\nSpeaker 11: (01:00:35)',
#  '\nSpeaker 18: (53:17)',
#  'Donald Trump: (01:24:00)',
#  'Donald Trump: (01:40:48)',
#  '\nDavid Hines: (13:39)',
#  'Donald Trump: (01:29:45)',
#  '\nAudience: (48:33)',
#  '\nSpeaker 4: (23:35)',
#  '\nDr. Fauci: (01:20:30)',
#  '\nSteve: (08:15)',
#  'Donald Trump: (38:12)',
#  'Donald Trump: (14:50)',
#  'Donald Trump: (16:57)',
#  'Donald Trump: (15:09)',
#  '\nMike Pence: (28:17)',
#  '\nSpeaker 28: (02:09:52)',
#  '\nTony Lowden: (37:16)',
#  '\nMike Pompeo: (19:06)',
#  '\nDr. Birx: (01:12:41)',
#  '\nMike Pence: (30:36)',
#  'Donald Trump: (11:50)',
#  '\nJim: (01:29:50)',
#  '\nVice President Mike Pence: (01:28:10)',
#  '\nChad Wolf: (22:52)',
#  '\nDaniel: (21:25)',
#  '\nPresident Donald Trump: (03:37)',
#  'Donald Trump: (26:44)',
#  '\nSpeaker 14: (34:29)',
#  '\nDoctor Birx: (01:40:26)',
#  '\nBill Hemmer: (05:22)',
#  '\nModerator: (01:33:51)',
#  '\nSpeaker 17: (01:09:14)',
#  '\nAudience: (11:06)',
#  '\nSpeaker 52: (39:15)',
#  '\nPeter Novarro: (29:57)',
#  '\nDr. Birx: (36:49)',
#  '\nRob Peston: (01:18:41)',
#  '\nPresident Trump: (02:15)',
#  '\nReporters: (06:09)',
#  'Donald Trump: (28:57)',
#  '\nDr. Deborah Birx: (01:02:19)',
#  '\nDeborah Birx: (35:22)',
#  '\nDr. Birx: (35:19)',
#  '\nDr. Deborah Birx: (02:04:59)',
#  '\nSpeaker 14: (34:50)',
#  '\nSpeaker 5: (50:46)',
#  'Donald Trump: (28:34)',
#  '\nSpeaker 10: (33:57)',
#  '\nDr. Birx: (01:33:42)',
#  'Donald Trump: (09:18)',
#  '\nSpeaker 16: (55:26)',
#  '\nSpeaker 11: (01:06:35)',
#  '\nMr. Chan: (01:23:54)',
#  '\nMike Pence: (01:32:56)',
#  'Donald Trump: (50:12)',
#  '\nThomas Moriarty: (14:09)',
#  'Donald Trump: (01:40:09)',
#  'Donald Trump: (01:14:49)',
#  'Donald Trump: (13:11)',
#  '\nSpeaker 31: (01:12:18)',
#  '\nReporters: (22:44)',
#  'Donald Trump: (44:29)',
#  'Donald Trump: (25:35)',
#  '\nSpeaker 3: (09:49)',
#  '\nSpeaker 4: (25:58)',
#  '\nGroup: (44:33)',
#  'Donald Trump: (49:42)',
#  '\nMark Esper: (00:31)',
#  '\nSpeaker 14: (34:36)',
#  '\nSpeaker 58: (53:30)',
#  '\nSpeaker 14: (01:04:47)',
#  'Donald Trump: (01:32:38)',
#  '\nSpeaker 4: (20:18)',
#  'Donald Trump: (02:02:32)',
#  '\nMike Pence: (07:10)',
#  'Donald Trump: (02:06)',
#  'Donald Trump: (18:23)',
#  'Donald Trump: (01:07:28)',
#  'Donald Trump: (01:20:20)',
#  '\nPeter: (44:31)',
#  '\nAudience Member: (01:17:56)',
#  '\nReporter: (01:08:32)',
#  '\nRobert Bresnahan: (07:56)',
#  '\nAudience Member: (01:24:13)',
#  'Donald Trump: (08:48)',
#  'Donald Trump: (28:30)',
#  'Donald Trump: (34:29)',
#  '\nPresident Trump: (52:33)',
#  '\nDavid Kong: (06:29)',
#  '\nPresident Trump: (33:53)',
#  '\nBrian Kemp: (26:03)',
#  'Donald Trump: (40:12)',
#  '\nSpeaker 31: (55:17)',
#  '\nBill Hemmer: (04:06)',
#  '\nAudience: (59:29)',
#  'Donald Trump: (01:26:05)',
#  '\nSpeaker 22: (01:13:13)',
#  '\nChuck Grassley: (52:38)',
#  '\nPresident Trump: (24:06)',
#  '\nMike Pence: (23:07)',
#  'Donald Trump: (01:35:29)',
#  'Donald Trump: (57:20)',
#  'Donald Trump: (31:16)',
#  'Donald Trump: (51:47)',
#  '\nAlex: (57:18)',
#  '\nSpeaker 4: (01:29)',
#  '\nSema Verma: (54:00)',
#  'Donald Trump: (10:18)',
#  '\nJonathan: (01:02:48)',
#  '\nDr. Birx: (01:29:56)',
#  '\nSpeaker 23: (01:03:18)',
#  '\nSpeaker 3: (01:24:19)',
#  'Donald Trump: (37:15)',
#  'Donald Trump: (10:42)',
#  '\nPeter Navarro: (01:04:10)',
#  '\nSpeaker 15: (01:12:05)',
#  '\nPresident Trump: (39:17)',
#  '\nDr. Deborah Birx: (01:02:59)',
#  'Donald Trump: (01:13:15)',
#  'Donald Trump: (03:16)',
#  '\nPresident Trump: (14:13)',
#  'Donald Trump: (13:59)',
#  'Donald Trump: (35:27)',
#  'Donald Trump: (48:19)',
#  '\nLarry Kudlow: (24:16)',
#  'Donald Trump: (42:03)',
#  '\nPresident Donald Trump: (06:03)',
#  'Donald Trump: (35:57)',
#  'Donald Trump: (01:05:28)',
#  '\nCrowd: (40:41)',
#  'Donald Trump: (12:16)',
#  '\nSurgeon General Jerome Adams: (46:35)',
#  '\nSpeaker 16: (01:29:44)',
#  'Donald Trump: (48:25)',
#  '\nTony Fauci: (32:25)',
#  '\nJournalist 16: (01:44:56)',
#  '\nSteve: (01:13:08)',
#  'Donald Trump: (01:09:31)',
#  '\nInterpreter: (11:42)',
#  '\nSec. Pompeo: (01:03:30)',
#  'Donald Trump: (01:02:20)',
#  'Donald Trump: (42:42)',
#  '\nKevin McCarthy: (01:24)',
#  'Donald Trump: (11:07)',
#  'Donald Trump: (58:44)',
#  '\nSpeaker 19: (53:54)',
#  'Donald Trump: (13:05)',
#  '\nAlex: (56:40)',
#  'Donald Trump: (27:24)',
#  '\nSpeaker 27: (01:16:39)',
#  'Donald Trump: (44:21)',
#  '\nSpeaker 5: (06:16)',
#  '\nMike Pence: (32:40)',
#  '\nKellyanne: (01:04:02)',
#  '\nScalia: (01:01:52)',
#  '\nReporter #5: (01:17:28)',
#  'Donald Trump: (57:55)',
#  '\nDr. Fauci: (39:12)',
#  'Donald Trump: (38:25)',
#  '\nPresident Trump: (43:32)',
#  '\nBret Baier: (09:47)',
#  '\nDr. Fauci: (01:07:05)',
#  'Donald Trump: (01:14:52)',
#  '\nSpeaker 14: (01:03:32)',
#  '\nSpeaker 1: (29:28)',
#  '\nPresident Donald Trump: (01:16:51)',
#  '\nSema Verma: (51:52)',
#  '\nDr. Birx: (01:34:15)',
#  'Donald Trump: (54:53)',
#  '\nDr. Deborah Birx: (31:15)',
#  '\nMike Pence: (12:35)',
#  'Donald Trump: (01:01:23)',
#  'Donald Trump: (07:58)',
#  '\nMike Pence: (34:37)',
#  '\nPete: (26:26)',
#  '\nSecretary Chad Wolf: (41:12)',
#  '\nSpeaker 12: (19:45)',
#  '\nSpeaker 9: (54:42)',
#  'Donald Trump: (29:26)',
#  'Donald Trump: (43:13)',
#  '\nReporter 1: (04:50)',
#  'Donald Trump: (39:26)',
#  'Donald Trump: (10:58)',
#  'Donald Trump: (50:47)',
#  'Donald Trump: (01:11:00)',
#  'Donald Trump: (23:40)',
#  '\nSpeaker 2: (11:26)',
#  '\nBill Hemmer: (38:22)',
#  '\nMark Esper: (35:27)',
#  '\nPeter Novarro: (28:21)',
#  '\nMike Pence: (29:13)',
#  '\nSpeaker 8: (03:32)',
#  '\nDr. Anthony Fauci: (33:35)',
#  '\nDoctor Birx: (59:23)',
#  'Donald Trump: (11:00)',
#  'Donald Trump: (01:13:45)',
#  '\nSpeaker 19: (59:31)',
#  '\nReporter #5: (01:16:32)',
#  '\nSpeaker 10: (01:07:26)',
#  '\nKelly: (42:04)',
#  '\nSteve: (01:11:31)',
#  '\nBill Hemmer: (43:34)',
#  '\nReporter 1: (07:35)',
#  '\nDr. Anthony Fauci: (01:10:36)',
#  '\nSpeaker 15: (34:28)',
#  '\nMike Pence: (29:15)',
#  '\nSpeaker 26: (01:20:05)',
#  '\nDeborah Birx: (15:01)',
#  '\nSteve Mnuchin: (14:37)',
#  '\nSteven: (39:42)',
#  'Donald Trump: (01:35:27)',
#  'Donald Trump: (05:47)',
#  '\nMike Lindell: (18:04)',
#  '\nSpeaker 14: (32:24)',
#  '\nSpeaker 6: (01:39:16)',
#  '\nDonald J Trump: (07:24)',
#  '\nDr. Deborah Birx: (01:05:23)',
#  'Donald Trump: (01:14:58)',
#  '\nDr. Fauci: (01:11:18)',
#  '\nMike Pence: (59:25)',
#  '\nSpeaker 6: (22:49)',
#  'Donald Trump: (23:32)',
#  '\nPresident Donald Trump: (05:16)',
#  '\nSpeaker 66: (01:10:56)',
#  '\nJohn: (52:39)',
#  '\nReporter 9: (01:12:45)',
#  '\nSpeaker 18: (01:35:26)',
#  '\nJohn: (01:00:55)',
#  'Donald Trump: (48:17)',
#  'Donald Trump: (35:26)',
#  'Donald Trump: (15:41)',
#  '\nSpeaker 11: (32:32)',
#  '\nAlex Azar: (27:03)',
#  '\nDr. Birx: (56:59)',
#  'Donald Trump: (20:59)',
#  '\nHunter Richer: (01:25:28)',
#  'Donald Trump: (46:20)',
#  'Donald Trump: (36:13)',
#  'Donald Trump: (01:08:02)',
#  '\nSpeaker 16: (39:54)',
#  '\nMike Pence: (31:34)',
#  '\nRobert Redfield: (09:11)',
#  '\nKelly: (55:07)',
#  '\nDeborah Birx: (35:12)',
#  'Donald Trump: (17:40)',
#  '\nDonald J Trump: (12:34)',
#  '\nDr. Fauci: (57:19)',
#  '\nDr. Fauci: (36:33)',
#  '\nDeborah Birx: (04:10)',
#  '\nVice President Mike Pence: (01:29:43)',
#  '\nDeborah Birx: (01:08:52)',
#  '\nJim Acosta: (40:32)',
#  '\nMike Pompeo: (28:57)',
#  'Donald Trump: (01:04:13)',
#  '\nMartha MacCallum: (16:37)',
#  '\nSpeaker 4: (13:02)',
#  '\nDr Fauci: (33:37)',
#  '\nSpeaker 26: (01:20:20)',
#  '\nVanessa: (49:22)',
#  'Donald Trump: (47:15)',
#  'Donald Trump: (59:30)',
#  '\nJosh: (01:25:45)',
#  'Donald Trump: (11:03)',
#  '\nMike Pence: (01:53:54)',
#  '\nMark H.: (14:36)',
#  '\nMale Reporter: (01:31:50)',
#  '\nMike Pence: (45:21)',
#  '\nVice President Pence: (13:07)',
#  '\nGary: (21:12)',
#  '\nPresident Trump: (05:37)',
#  '\nSpeaker 2: (09:36)',
#  'Donald Trump: (40:01)',
#  'Donald Trump: (05:22)',
#  '\nSpeaker 26: (01:15:34)',
#  '\nSpeaker 12: (01:02:56)',
#  'Donald Trump: (02:46)',
#  'Donald Trump: (35:47)',
#  '\nPresident Trump: (21:23)',
#  '\nMike Pence: (29:11)',
#  '\nMike Pence: (42:36)',
#  '\nJohn Shiver: (12:03)',
#  '\nMike Pence: (40:58)',
#  '\nSpeaker 15: (21:15)',
#  '\nSpeaker 10: (31:08)',
#  '\nVanessa: (50:04)',
#  '\nRobin Hayes: (11:11)',
#  'Donald Trump: (14:43)',
#  '\nJennifer: (11:58)',
#  'Donald Trump: (43:03)',
#  '\nSpeaker 13: (01:16:03)',
#  'Donald Trump: (06:20)',
#  'Donald Trump: (27:04)',
#  'Donald Trump: (44:05)',
#  'Donald Trump: (54:14)',
#  '\nSteve Monroe: (07:21)',
#  '\nDonald J Trump: (04:05)',
#  'Donald Trump: (01:09:03)',
#  '\nDr. Birx: (51:10)',
#  'Donald Trump: (36:17)',
#  'Donald Trump: (46:35)',
#  'Donald Trump: (13:15)',
#  '\nSeema Verma: (27:37)',
#  'Donald Trump: (29:37)',
#  '\nSpeaker 6: (31:03)',
#  'Donald Trump: (06:52)',
#  '\nPresident Trump: (41:48)',
#  'Donald Trump: (02:00:47)',
#  '\nSpeaker 6: (01:07:33)',
#  '\nReporter 3: (14:15)',
#  'Donald Trump: (02:06:35)',
#  '\nSteve Mnuchin: (33:34)',
#  '\nPresident Trump: (35:54)',
#  'Donald Trump: (01:04:28)',
#  '\nAdmiral Giroir: (38:11)',
#  '\nDr. Birx: (12:35)',
#  'Donald Trump: (01:03:52)',
#  '\nDaniel: (23:13)',
#  '\nSpeaker 19: (58:01)',
#  '\nAudience: (10:57)',
#  'Donald Trump: (01:39:51)',
#  '\nDr. Deborah Birx: (50:14)',
#  'Donald Trump: (49:39)',
#  'Donald Trump: (12:45)',
#  '\nSpeaker 2: (41:02)',
#  'Donald Trump: (29:50)',
#  '\nJohn: (01:10:21)',
#  'Donald Trump: (27:40)',
#  '\nReporter 1: (02:08)',
#  '\nJerome Adams: (30:35)',
#  '\nAudience: (08:34)',
#  '\nReporter 4: (01:52:19)',
#  'Donald Trump: (15:53)',
#  '\nSpeaker 34: (59:24)',
#  '\nReporter 4: (01:01:06)',
#  '\nGreg Hayes: (25:14)',
#  '\nSpeaker 6: (22:28)',
#  '\nYamiche Alcindor: (46:13)',
#  'Donald Trump: (01:24:22)',
#  '\nAlex Azar: (46:36)',
#  '\nSpeaker 9: (29:02)',
#  '\nRobert Redfield: (08:00)',
#  '\nDr. Deborah Birx: (01:58:09)',
#  '\nSpeaker 3: (29:12)',
#  '\nMale Reporter: (01:24:16)',
#  '\nDebra Waller: (21:29)',
#  'Donald Trump: (01:41:23)',
#  'Donald Trump: (28:27)',
#  '\nPresident Trump: (22:22)',
#  '\nSpeaker 9: (54:14)',
#  '\nDr. Fauci: (01:35:08)',
#  'Donald Trump: (01:11:43)',
#  'Donald Trump: (01:09:26)',
#  '\nJohn: (01:20:35)',
#  '\nSeema Verma: (30:35)',
#  'Donald Trump: (12:42)',
#  '\nSpeaker 3: (43:06)',
#  'Donald Trump: (40:09)',
#  'Donald Trump: (01:45:03)',
#  '\nSpeaker 4: (05:59)',
#  '\nSpeaker 8: (59:16)',
#  'Donald Trump: (01:26:26)',
#  '\nSpeaker 12: (18:52)',
#  '\nBret Baier: (07:21)',
#  '\nGroup: (49:18)',
#  'Donald Trump: (13:26)',
#  '\nDr. Deborah Birx: (52:35)',
#  '\nSpeaker 28: (01:09:06)',
#  '\nJohn: (00:58)',
#  '\nCrowd: (34:37)',
#  '\nFrancis Collins: (00:42)',
#  '\nReporter: (44:11)',
#  '\nDr. Birx: (22:46)',
#  '\nBret Baier: (13:10)',
#  '\nReporters: (09:34)',
#  '\nVice President Pence: (15:27)',
#  '\nDeborah Birx: (28:46)',
#  '\nJoseph Kim: (30:11)',
#  '\nJennifer: (01:08:03)',
#  '\nDeborah Birx: (01:00:17)',
#  '\nSpeaker 11: (15:35)',
#  'Donald Trump: (01:24:53)',
#  '\nDoctor: (24:12)',
#  'Donald Trump: (37:11)',
#  '\nPresident Donald Trump: (21:58)',
#  '\nSpeaker 1: (19:03)',
#  '\nSpeaker 12: (01:03:46)',
#  '\nSpeaker 32: (01:13:21)',
#  '\nSpeaker 14: (38:10)',
#  'Donald Trump: (01:08:42)',
#  '\nCrowd: (01:32:18)',
#  '\nMike Pence: (01:04:13)',
#  '\nPresident Trump: (06:43)',
#  '\nSpeaker 35: (59:26)',
#  'Donald Trump: (02:07)',
#  '\nSpeaker 15: (01:04:34)',
#  'Donald Trump: (31:42)',
#  'Donald Trump: (03:24)',
#  'Donald Trump: (01:08:31)',
#  'Donald Trump: (01:14:45)',
#  '\nMike Pence: (41:37)',
#  'Donald Trump: (00:31)',
#  'Donald Trump: (31:39)',
#  '\nMike Pence: (52:54)',
#  'Donald Trump: (43:09)',
#  '\nPresident Trump: (11:45)',
#  '\nMike Pence: (22:52)',
#  '\nMike Pence: (38:51)',
#  '\nDr. Deborah Birx: (01:01:56)',
#  '\nMacron: (25:28)',
#  '\nSpeaker 6: (01:10:44)',
#  '\nDoctor Birx: (01:00:40)',
#  '\nAdmiral Gilday: (32:33)',
#  'Donald Trump: (01:48:59)',
#  '\nJeff: (01:48:51)',
#  'Donald Trump: (01:17:14)',
#  'Donald Trump: (13:37)',
#  'Donald Trump: (01:45:18)',
#  'Donald Trump: (03:27)',
#  'Donald Trump: (01:11:51)',
#  '\nTravis: (30:44)',
#  '\nMike Pence: (15:35)',
#  'Donald Trump: (00:49)',
#  '\nSpeaker 22: (01:10:35)',
#  '\nSpeaker 8: (01:14:55)',
#  '\nSpeaker 5: (39:57)',
#  '\nAdmiral Giroir: (51:45)',
#  '\nJohn: (20:47)',
#  'Donald Trump: (29:24)',
#  '\nSecretary Azar: (26:05)',
#  '\nMike Pence: (23:52)',
#  '\nSpeaker 9: (54:15)',
#  'Donald Trump: (01:29:38)',
#  '\nDonald J Trump: (03:05)',
#  '\nPresident Trump: (24:01)',
#  '\nMartha MacCallum: (09:50)',
#  '\nSpeaker 10: (28:18)',
#  '\nMark Esper: (00:47)',
#  'Donald Trump: (27:32)',
#  'Donald Trump: (01:26:34)',
#  '\nReporters: (32:31)',
#  'Donald Trump: (11:14)',
#  '\nSurgeon General Jerome Adams: (30:20)',
#  '\nAlex Azar: (31:45)',
#  'Donald Trump: (01:00:56)',
#  '\nDeborah Birx: (01:29:48)',
#  'Donald Trump: (01:16:41)',
#  'Donald Trump: (01:27:22)',
#  '\nSpeaker 5: (45:24)',
#  '\nSpeaker 16: (39:31)',
#  'Donald Trump: (01:05:39)',
#  '\nRobert Redfield: (05:04)',
#  '\nSpeaker 10: (13:29)',
#  '\nDr. Birx: (17:59)',
#  '\nAdmiral Gilday: (32:21)',
#  '\nSpeaker 7: (23:40)',
#  'Donald Trump: (35:07)',
#  'Donald Trump: (29:48)',
#  '\nPeter: (47:26)',
#  '\nPeter Navarro: (06:09)',
#  '\nReporter 4: (59:00)',
#  '\nSpeaker 6: (53:35)',
#  '\nDr. Birx: (01:28:07)',
#  '\nAudience: (35:11)',
#  '\nMike Pence: (01:18:12)',
#  'Donald Trump: (06:31)',
#  '\nSpeaker 2: (26:00)',
#  '\nDr. Berks: (31:05)',
#  '\nKaitlin: (48:08)',
#  '\nSpeaker 22: (01:02:45)',
#  'Donald Trump: (32:56)',
#  '\nReporters: (09:35)',
#  '\nSpeaker 3: (26:31)',
#  '\nReporter 9: (02:11:16)',
#  'Donald Trump: (31:43)',
#  '\nSpeaker 16: (33:02)',
#  'Donald Trump: (05:18)',
#  'Donald Trump: (04:20)',
#  'Donald Trump: (18:51)',
#  '\nVice President Pence: (36:44)',
#  'Donald Trump: (56:50)',
#  '\nJournalist 10: (01:35:41)',
#  '\nSpeaker 6: (05:32)',
#  'Donald Trump: (01:25:57)',
#  '\nJohn: (01:06:19)',
#  'Donald Trump: (01:36:11)',
#  'Donald Trump: (30:34)',
#  '\nSpeaker 9: (17:03)',
#  '\nPresident Trump: (33:45)',
#  '\nBen: (00:09)',
#  'Donald Trump: (01:10:52)',
#  'Donald Trump: (04:25)',
#  '\nSpeaker 13: (50:34)',
#  '\nDeborah Birx: (19:59)',
#  '\nDr. Deborah Birx: (01:08:17)',
#  '\nSpeaker 4: (15:25)',
#  'Donald Trump: (14:45)',
#  'Donald Trump: (09:29)',
#  '\nDonald J Trump: (12:25)',
#  '\nMike Pence: (17:54)',
#  '\nBret Baier: (06:43)',
#  '\nBob: (52:25)',
#  '\nSpeaker 22: (01:11:03)',
#  'Donald Trump: (09:00)',
#  'Donald Trump: (06:12)',
#  'Donald Trump: (01:30:21)',
#  '\nJohn Polowczyk: (34:07)',
#  '\nSpeaker 9: (44:29)',
#  'Donald Trump: (22:13)',
#  '\nJim Acosta: (48:45)',
#  '\nAudience: (14:02)',
#  '\nMike Pence: (03:38)',
#  '\nSpeaker 19: (01:24:45)',
#  '\nMike Pence: (35:47)',
#  'Donald Trump: (21:01)',
#  'Donald Trump: (40:41)',
#  'Donald Trump: (01:10:21)',
#  '\nReporter: (32:53)',
#  '\nYamiche A.: (47:44)',
#  'Donald Trump: (18:00)',
#  '\nMike Pence: (55:56)',
#  '\nAudience: (22:23)',
#  '\nJared Kushner: (01:47:54)',
#  '\nSpeaker 16: (38:59)',
#  '\nCrowd: (01:20:58)',
#  '\nSpeaker 9: (17:04)',
#  '\nVice President Pence: (01:22:24)',
#  'Donald Trump: (01:14:25)',
#  'Donald Trump: (47:29)',
#  '\nSpeaker 13: (33:34)',
#  '\nReporter: (01:12:27)',
#  'Donald Trump: (07:46)',
#  '\nSpeaker 21: (01:03:49)',
#  '\nJovita Carranza: (06:13)',
#  'Donald Trump: (03:33)',
#  '\nReporter: (49:38)',
#  'Donald Trump: (01:41)',
#  '\nSpeaker 14: (33:00)',
#  'Donald Trump: (17:24)',
#  'Donald Trump: (33:33)',
#  '\nMike Pence: (01:19:18)',
#  '\nSeema Verma: (38:04)',
#  'Donald Trump: (01:17:29)',
#  '\nSpeaker 6: (36:11)',
#  'Donald Trump: (34:57)',
#  '\nSpeaker 5: (36:59)',
#  'Donald Trump: (16:19)',
#  '\nPresident Trump: (09:07)',
#  '\nSpeaker 21: (01:22:44)',
#  'Donald Trump: (19:03)',
#  'Donald Trump: (10:38)',
#  'Donald Trump: (35:02)',
#  'Donald Trump: (01:08:43)',
#  '\nDr. Birx: (16:57)',
#  'Donald Trump: (25:09)',
#  'Donald Trump: (09:59)',
#  'Donald Trump: (10:25)',
#  '\nDr. Birx : (53:42)',
#  '\nSpeaker 19: (32:13)',
#  '\nSpeaker 10: (01:01:43)',
#  '\nDr Fauci: (27:21)',
#  '\nSwathi Chandrashekar: (31:52)',
#  'Donald Trump: (21:52)',
#  '\nAlex Azar: (19:18)',
#  '\nPeter Novarro: (28:44)',
#  '\nJim Acosta: (38:38)',
#  'Donald Trump: (37:34)',
#  '\nDr. Ben Carson: (47:30)',
#  '\nJournalist 9: (01:34:10)',
#  'Donald Trump: (01:59)',
#  'Donald Trump: (50:21)',
#  'Donald Trump: (01:24:24)',
#  '\nDeborah Birx: (01:09:50)',
#  'Donald Trump: (43:55)',
#  '\nAudience: (17:07)',
#  'Donald Trump: (53:49)',
#  '\nMike Pence: (01:24:56)',
#  '\nSpeaker 11: (52:16)',
#  '\nSpeaker 3: (44:30)',
#  'Donald Trump: (15:36)',
#  '\nSpeaker 13: (01:09:27)',
#  '\nPresident Trump: (53:07)',
#  '\nDr. Deborah Birx: (33:13)',
#  '\nSpeaker 23: (01:06:49)',
#  '\nMike Pence: (01:08:28)',
#  '\nJournalist 2: (01:14:45)',
#  '\nSec. Pompeo: (01:09:12)',
#  '\nSpeaker 19: (22:03)',
#  '\nSec. Pompeo: (59:21)',
#  '\nSpeaker 18: (01:35:34)',
#  'Donald Trump: (01:25:11)',
#  '\nMike Pence: (16:24)',
#  'Donald Trump: (53:43)',
#  '\nSema Verma: (52:49)',
#  '\nKellyanne: (01:05:07)',
#  '\nSpeaker 6: (17:23)',
#  'Donald Trump: (33:50)',
#  '\nMacron: (43:49)',
#  '\nAdmiral Gilday: (32:24)',
#  '\nSpeaker 19: (38:09)',
#  'Donald Trump: (01:24:19)',
#  'Donald Trump: (01:25:02)',
#  '\nSpeaker 11: (49:13)',
#  '\nJeff: (01:04:40)',
#  '\nJerome Adams: (01:15:18)',
#  'Donald Trump: (34:58)',
#  '\nSteve Mnuchin: (37:12)',
#  'Donald Trump: (36:11)',
#  'Donald Trump: (01:18)',
#  'Donald Trump: (42:39)',
#  'Donald Trump: (52:28)',
#  '\nSpeaker 61: (01:02:13)',
#  '\nMike Pence: (01:04:35)',
#  '\nFemale Reporter: (01:31:05)',
#  '\nSpeaker 13: (01:08:31)',
#  '\nReporter #6: (49:42)',
#  '\nRobert Wilkie: (41:40)',
#  '\nJohn Mascola: (11:13)',
#  'Donald Trump: (47:23)',
#  '\nSpeaker 10: (47:58)',
#  ...]

# %%
files_dict2={}
for key, item in files_dict.items():
    if re.search(search_for_speaker, item):
        print(key)
        x=re.split(search_for_speaker, item)
        z=x[1:]
        #[i for i in x if i!='']
        print(len(z))
        #print(z)
        final_list=[]
        for index, elem in enumerate(z):
            if (index - 1 >= 0):
                if index % 2 == 1 and len(z) % 2 ==0:
                    prev_el = str(z[index-1])
                    curr_el = str(elem)
                    if re.search(search_for_donald, prev_el):
                        final_list.append(curr_el)
                        #final_list2=final_list
                        final_list2="".join(final_list)
    else:
        final_list2=item
    text=final_list2.replace('(Applause.)', '').replace('(Laughter.)', '').replace('(APPLAUSE)', '')
    text=text.strip()
    files_dict2[key]=text
# Out:
# 2019.07.05 Donald Trump 4th of July Event Speech Transcript.txt
# 46
# 2019.07.23 Donald Trump Speech Transcript Turning Point USA Teen Student Summit Speech.txt
# 432
# 2019.07.30 Donald Trump Speech Transcript in Jamestown Virginia.txt
# 110
# 2019.08.05 Donald Trump Statement on Mass Shootings.txt
# 24
# 2019.08.26 Donald Trump, Emmanuel Macron G7 Press Conference & Speeches.txt
# 406
# 2019.09.11 E-Cigarette Regulation and John Bolton Discussion.txt
# 86
# 2019.09.25 Press Conference Response to Impechment Inquiry.txt
# 188
# 2019.10.03 Trump Transcript Trump Says China Should Investigate Biden.txt
# 52
# 2019.10.04 Trump Claims No Quid Pro Quo.txt
# 146
# 2019.10.16 Press Conference with Italian President.txt
# 306
# 2019.10.22 Donald Trump Cabinet Meeting Transcript Trump Calls Emoluments Clause of the Constitution Phony.txt
# 296
# 2019.10.23 Donald Trump Syria Press Conference Transcript Trump Orders All Turkey Sanctions Lifted.txt
# 40
# 2019.10.27 ISIS Leader Abu Bakr al-Baghdadi Killed.txt
# 308
# 2019.12.03 Macron Trump NATO Summit Meeting Transcript.txt
# 156
# 2020.01.03 Donald Trump Iran Statement Speech Trump Orders Stike on Qasem Soleimani.txt
# 10
# 2020.01.08 Trump Makes Statement After Iran Attacks US Bases in Iraq.txt
# 18
# 2020.01.22 Davos World Economic Forum Trump Holds News Conference.txt
# 232
# 2020.01.24 Trump Speaks at March for Life Event.txt
# 22
# 2020.01.28 Middle East Peace Speech Transcript with Israel PM Netanyahu.txt
# 108
# 2020.02.06 National Prayer Breakfast.txt
# 54
# 2020.02.06 News Conference Calls Russia Investigation Bullshit Talks Impeachment Acquittal.txt
# 184
# 2020.02.07 Opportunity Now Summit in Charlotte NC.txt
# 144
# 2020.02.10 National Governors Association Speech Transcript.txt
# 138
# 2020.02.11 Donald Trump Talks Roger Stone Colonel Vindman During Veteran Bill Signing.txt
# 68
# 2020.02.16 Daytona 500 Speech Trump First President as Daytona Grand Marshal.txt
# 12
# 2020.02.18 Trump Speaks About Communiting Former Gov Blagojevich Stence Pardoning Others.txt
# 204
# 2020.02.20 Donald Trump Speech Transcript at the Hope for Prisoners Graduation Ceremony.txt
# 154
# 2020.02.25 New Delha News Conference.txt
# 286
# 2020.02.26 Coronavirus Press Conference Trump and CDC Give Coronavirus Updates.txt
# 294
# 2020.02.29 Coronavirus Update Transcript Warns Not To Travel to Italy South Korea.txt
# 258
# 2020.03.02 Trump Holds Coronavirus Meeting with Pharmaceutical Executives.txt
# 540
# 2020.03.03 Meeting wiht the National Institute of Health.txt
# 154
# 2020.03.03 National Association of Counties Speech.txt
# 144
# 2020.03.04 Donald Trump Mike Pence Coronavirus Briefing with Airline and Diagnostic Lab CEOs.txt
# 172
# 2020.03.06 Donald Trump Visits CDC Calls Jay Inslee a Snake.txt
# 392
# 2020.03.06 Fox News Town Hall Transcript.txt
# 402
# 2020.03.10 Donald Trump and Mike Pene Meet With Health Insurance Amid Coronavirus.txt
# 40
# 2020.03.10 Donald Trump Signs 8 point 3 Billion Coronavirus Spending Bill.txt
# 88
# 2020.03.11 Bank CEOs Announce Coronavius Measures.txt
# 216
# 2020.03.11 Coronavirus Ban on Europe Travel.txt
# 18
# 2020.03.12 Trump Meeting with Acting Irish Prime Minish Leo Varadkar.txt
# 224
# 2020.03.13 Declares Coronavirus National Emergency.txt
# 422
# 2020.03.14 Coronavirus Press Conference.txt
# 284
# 2020.03.15 Coronavirus Task Force News Conference.txt
# 204
# 2020.03.16 Coronavirus Task Force Update.txt
# 450
# 2020.03.17 Coronavirus Task Force Briefing - Trump Pence Mnuchin Speak about Covid 19.txt
# 548
# 2020.03.17 Meeting with Tourism Industry Reps Amid Coronavirus Pandemic.txt
# 240
# 2020.03.18 Coronavirus Task Force News Briefing Invokes Defense Production Act.txt
# 474
# 2020.03.19 Task Force Briefing Trump Takes Shots at the Media.txt
# 478
# 2020.03.20 Coronavirus Task Force Trump Spars with Reporters.txt
# 616
# 2020.03.20 Coronavirus Task Force Update.txt
# 492
# 2020.03.22 Coronavirus Task Force Briefing National Guard Activated in New York California and Washington State.txt
# 510
# 2020.03.23 Coronavirus Task Force Briefing.txt
# 638
# 2020.03.24 Coronavirus Task Force Briefing.txt
# 142
# 2020.03.24 Coronavirus Town Hall Transcript Trump Wants to Restart the Economy by Easter.txt
# 382
# 2020.03.25 Coronavirus Task Force Press Conference Transcript March 25.txt
# 316
# 2020.03.26 Coronavirus Task Force Press Conference Transcript Plans to Classify Counties by COVID 19 Risk.txt
# 290
# 2020.03.27 Coronavirus Task Force Briefing Trump Says Michigan and Washington Governors Not “Appreciative”.txt
# 428
# 2020.03.27 Donald Trump Signs Historic $2 Trillion Coronavirus Stimulus Bill.txt
# 24
# 2020.03.28 Donald Trump Gives Speech Sending off Hospital Ship to NYC.txt
# 82
# 2020.03.29 Coronavirus Task Force Briefing Transcript March 29.txt
# 598
# 2020.03.30 Coronavirus Task Force Press Conference Transcript March 30.txt
# 278
# 2020.03.31 Coronavirus Task Force Briefing Transcript March 31 “Painful” Weeks Ahead.txt
# 672
# 2020.04.01 Coronavirus Task Force Briefing Transcripts.txt
# 646
# 2020.04.02 Coronavirus Task Force Briefing April 2.txt
# 688
# 2020.04.03 Coronavirus Briefing Transcript April 3 New CDC Face Mask Recommendations.txt
# 468

# %%
files_df=pd.DataFrame.from_dict(files_dict2, orient='index', columns=['text']).reset_index()

# %%
files_df['date']=pd.to_datetime(files_df['index'].str[:10].replace('.', "/")).dt.strftime('%Y/%m/%d %H:%M:%S')

# %%
files_df['title']=files_df['index'].str[11:]
files_df['title']=files_df['title'].str.split(".").str[0]
files_df['candidate']='trump'
files_df['event_type']='speech'
files_df['campaign_related']=np.NaN
files_df['city']=np.NaN
files_df['state']=np.NaN
files_df['source']='https://www.rev.com/blog/transcript-category/donald-trump-transcripts/'

# %%
files_df=files_df[['candidate', 'date', 'title', 'event_type', 'city', 'state', 'campaign_related', 'text', 'source']]

# %%
files_df.to_csv(inpath2+'rev.csv', index=False)
